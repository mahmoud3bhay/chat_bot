# %%
# Mounting the Google Drive
#uploading intents json file to google drive 
from google.colab import drive
drive.mount('/content/drive')
data_root='/content/drive/MyDrive/ChatBot'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import string
import random 

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#3 Loading the Dataset: intents.json

data_file = open(data_root + '/intents.json').read()
data = json.loads(data_file)

data
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi', 'How are you', 'Is anyone there?', 'Hello', 'Good day'],
#    'responses': ['Hello, thanks for visiting',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context_set': ''},
#   {'tag': 'goodbye',
#    'patterns': ['Bye', 'See you later', 'Goodbye'],
#    'responses': ['See you later, thanks for visiting',
#     'Have a nice day',
#     'Bye! Come back again soon.']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks', 'Thank you', "That's helpful"],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure']},
#   {'tag': 'hours',
#    'patterns': ['What hours are you open?',
#     'What are your hours?',
#     'When are you open?'],
#    'responses': ["We're open every day 9am-9pm",
#     'Our hours are 9am-9pm every day']},
#   {'tag': 'payments',
#    'patterns': ['Do you take credit cards?',
#     'Do you accept Mastercard?',
#     'Are you cash only?'],
#    'responses': ['We accept VISA, Mastercard and AMEX',
#     'We accept most major credit cards']},
#   {'tag': 'opentoday',
#    'patterns': ['Are you open today?',
#     'When do you open today?',
#     'What are your hours today?'],
#    'responses': ["We're open every day from 9am-9pm",
#     'Our hours are 9am-9pm every day']},
#   {'tag': 'weathertoday',
#    'patterns': ['What is weather today?', "What is today's temprature?"],
#    'responses': ['weather today : 30']},
#   {'tag': 'weathertomorrow',
#    'patterns': ['What will be weather tomorrow?',
#     "What will be tomorrow's temprature?"],
#    'responses': ['weather tomorrow : 40']}]}

# %%
#4 Extracting data_X(features) and data_Y(Target)

words = [] #For Bow model/ vocabulary for patterns
classes = [] #For Bow  model/ vocabulary for tags
data_X = [] #For storing each pattern
data_y = [] #For storing tag corresponding to each pattern in data_X 
# Iterating over all the intents

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern) # tokenize each pattern 
        words.extend(tokens) #and append tokens to words
        data_X.append(pattern) #appending pattern to data_X
        data_y.append(intent["tag"]) ,# appending the associated tag to each pattern 
    
    # adding the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# 5 Text to Numbers
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(data_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
#adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=130, verbose=1)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               4992
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 8)                 520
#
# =================================================================
# Total params: 13,768
# Trainable params: 13,768
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/130
# 1/1 [==============================] - 1s 818ms/step - loss: 2.2572 - accuracy: 0.0417
# Epoch 2/130
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0898 - accuracy: 0.0833
# Epoch 3/130
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0695 - accuracy: 0.1250
# Epoch 4/130
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1025 - accuracy: 0.2083
# Epoch 5/130
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0602 - accuracy: 0.1667
# Epoch 6/130
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0883 - accuracy: 0.1250
# Epoch 7/130
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0445 - accuracy: 0.1667
# Epoch 8/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9745 - accuracy: 0.2083
# Epoch 9/130
# 1/1 [==============================] - 0s 16ms/step - loss: 2.1453 - accuracy: 0.0833
# Epoch 10/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9598 - accuracy: 0.2917
# Epoch 11/130
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0272 - accuracy: 0.2917
# Epoch 12/130
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0130 - accuracy: 0.1250
# Epoch 13/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9849 - accuracy: 0.0833
# Epoch 14/130
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9740 - accuracy: 0.2500
# Epoch 15/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9873 - accuracy: 0.1667
# Epoch 16/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9624 - accuracy: 0.0833
# Epoch 17/130
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0577 - accuracy: 0.1667
# Epoch 18/130
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9728 - accuracy: 0.2917
# Epoch 19/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9140 - accuracy: 0.2917
# Epoch 20/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9023 - accuracy: 0.3750
# Epoch 21/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8536 - accuracy: 0.3333
# Epoch 22/130
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8266 - accuracy: 0.3333
# Epoch 23/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8132 - accuracy: 0.4167
# Epoch 24/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8570 - accuracy: 0.4583
# Epoch 25/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.7748 - accuracy: 0.5417
# Epoch 26/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8107 - accuracy: 0.3750
# Epoch 27/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7782 - accuracy: 0.5833
# Epoch 28/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7554 - accuracy: 0.5417
# Epoch 29/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.6785 - accuracy: 0.5000
# Epoch 30/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7350 - accuracy: 0.4167
# Epoch 31/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6958 - accuracy: 0.5833
# Epoch 32/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.7259 - accuracy: 0.4167
# Epoch 33/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6278 - accuracy: 0.5833
# Epoch 34/130
# 1/1 [==============================] - 0s 15ms/step - loss: 1.6615 - accuracy: 0.6250
# Epoch 35/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.6424 - accuracy: 0.5000
# Epoch 36/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6207 - accuracy: 0.6250
# Epoch 37/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6287 - accuracy: 0.6250
# Epoch 38/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6746 - accuracy: 0.6667
# Epoch 39/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.6979 - accuracy: 0.5417
# Epoch 40/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6951 - accuracy: 0.4167
# Epoch 41/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5267 - accuracy: 0.5833
# Epoch 42/130
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5194 - accuracy: 0.5833
# Epoch 43/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5144 - accuracy: 0.5000
# Epoch 44/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4491 - accuracy: 0.6250
# Epoch 45/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5767 - accuracy: 0.5833
# Epoch 46/130
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4337 - accuracy: 0.8333
# Epoch 47/130
# 1/1 [==============================] - 0s 19ms/step - loss: 1.4774 - accuracy: 0.5417
# Epoch 48/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5162 - accuracy: 0.4583
# Epoch 49/130
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4497 - accuracy: 0.5833
# Epoch 50/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3636 - accuracy: 0.7500
# Epoch 51/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4204 - accuracy: 0.5833
# Epoch 52/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4183 - accuracy: 0.6250
# Epoch 53/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3630 - accuracy: 0.7500
# Epoch 54/130
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4321 - accuracy: 0.6250
# Epoch 55/130
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3667 - accuracy: 0.7500
# Epoch 56/130
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3683 - accuracy: 0.6250
# Epoch 57/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2487 - accuracy: 0.6667
# Epoch 58/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2264 - accuracy: 0.7500
# Epoch 59/130
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1991 - accuracy: 0.7083
# Epoch 60/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2945 - accuracy: 0.7083
# Epoch 61/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2162 - accuracy: 0.7083
# Epoch 62/130
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2280 - accuracy: 0.6250
# Epoch 63/130
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1520 - accuracy: 0.7500
# Epoch 64/130
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3482 - accuracy: 0.6250
# Epoch 65/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1222 - accuracy: 0.7083
# Epoch 66/130
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0862 - accuracy: 0.8333
# Epoch 67/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1710 - accuracy: 0.6250
# Epoch 68/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2057 - accuracy: 0.6667
# Epoch 69/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0212 - accuracy: 0.7083
# Epoch 70/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0577 - accuracy: 0.7500
# Epoch 71/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9715 - accuracy: 0.8333
# Epoch 72/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1884 - accuracy: 0.7500
# Epoch 73/130
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1218 - accuracy: 0.7500
# Epoch 74/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9496 - accuracy: 0.8333
# Epoch 75/130
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9361 - accuracy: 0.7917
# Epoch 76/130
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9635 - accuracy: 0.8333
# Epoch 77/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9621 - accuracy: 0.8333
# Epoch 78/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0141 - accuracy: 0.8750
# Epoch 79/130
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9519 - accuracy: 0.8750
# Epoch 80/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8644 - accuracy: 0.9167
# Epoch 81/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1081 - accuracy: 0.7917
# Epoch 82/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7968 - accuracy: 0.9167
# Epoch 83/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9647 - accuracy: 0.8333
# Epoch 84/130
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0519 - accuracy: 0.7500
# Epoch 85/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9470 - accuracy: 0.8750
# Epoch 86/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9696 - accuracy: 0.8333
# Epoch 87/130
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6884 - accuracy: 0.9167
# Epoch 88/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8902 - accuracy: 0.7917
# Epoch 89/130
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8517 - accuracy: 0.9167
# Epoch 90/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9364 - accuracy: 0.8333
# Epoch 91/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6962 - accuracy: 0.9167
# Epoch 92/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7183 - accuracy: 0.8750
# Epoch 93/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6879 - accuracy: 0.8750
# Epoch 94/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8381 - accuracy: 0.9167
# Epoch 95/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5753 - accuracy: 1.0000
# Epoch 96/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7970 - accuracy: 0.8333
# Epoch 97/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7994 - accuracy: 0.8333
# Epoch 98/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6866 - accuracy: 0.9583
# Epoch 99/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6803 - accuracy: 0.8750
# Epoch 100/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7716 - accuracy: 0.8750
# Epoch 101/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5255 - accuracy: 0.9583
# Epoch 102/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6327 - accuracy: 0.9583
# Epoch 103/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7114 - accuracy: 0.8750
# Epoch 104/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7534 - accuracy: 0.9167
# Epoch 105/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5400 - accuracy: 0.9583
# Epoch 106/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5852 - accuracy: 1.0000
# Epoch 107/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4550 - accuracy: 0.9167
# Epoch 108/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6482 - accuracy: 0.9583
# Epoch 109/130
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6304 - accuracy: 0.9167
# Epoch 110/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5162 - accuracy: 0.9167
# Epoch 111/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4661 - accuracy: 0.9583
# Epoch 112/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4873 - accuracy: 0.9583
# Epoch 113/130
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4744 - accuracy: 1.0000
# Epoch 114/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4767 - accuracy: 0.9167
# Epoch 115/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4445 - accuracy: 0.9583
# Epoch 116/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4914 - accuracy: 0.9583
# Epoch 117/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4796 - accuracy: 0.9167
# Epoch 118/130
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4641 - accuracy: 1.0000
# Epoch 119/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4083 - accuracy: 0.9583
# Epoch 120/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3434 - accuracy: 0.9167
# Epoch 121/130
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4629 - accuracy: 0.8750
# Epoch 122/130
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5533 - accuracy: 0.8333
# Epoch 123/130
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6034 - accuracy: 0.8750
# Epoch 124/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5430 - accuracy: 0.8750
# Epoch 125/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4462 - accuracy: 0.9167
# Epoch 126/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4081 - accuracy: 0.9583
# Epoch 127/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5762 - accuracy: 0.8750
# Epoch 128/130
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4312 - accuracy: 0.9583
# Epoch 129/130
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3651 - accuracy: 1.0000
# Epoch 130/130
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4558 - accuracy: 0.9583

# %%
#7 Preprocessing the Input

def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0] #Extracting probabilities
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True) #Sorting by values of probability in decreasing order
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]]) #Contains labels(tags) for highest probability 
  return return_list

def get_response(intents_list, intents_json): 
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents: 
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
# Interacting with the chatbot
print("Press 0 if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
      break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# Hi
# 1/1 [==============================] - 0s 22ms/step
# Sorry! I don't understand.
# hello
# 1/1 [==============================] - 0s 33ms/step
# Hi there, how can I help?
# is there anyone ?
# 1/1 [==============================] - 0s 27ms/step
# Hello, thanks for visiting
# hello
# 1/1 [==============================] - 0s 25ms/step
# Good to see you again
# what is the weather
# 1/1 [==============================] - 0s 25ms/step
# weather today : 30
# 0
